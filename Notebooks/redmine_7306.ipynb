# %%
import os
import sys

import django

sys.path.append('../')  # add path to project root dir

os.environ["DJANGO_SETTINGS_MODULE"] = "flourish.settings"
from django.apps import apps as django_apps

os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"

django.setup()
# Out:
#   * Reading config from flourish.ini
# Loading Data Encryption (init)...
#  * loading keys from /Users/nimrodmunatsi/source/flourish-code-space/flourish/crypto_fields
#  * loading rsa.restricted.public ... Done.
#  * loading rsa.restricted.private ... Done.
#  * loading rsa.local.public ... Done.
#  * loading rsa.local.private ... Done.
#  * loading aes.local ... Done.
#  * loading aes.restricted ... Done.
#  * loading salt.local ... Done.
#  * loading salt.restricted ... Done.
#  Done loading Data Encryption (init)...
# /Users/nimrodmunatsi/.venv/flourish/lib/python3.9/site-packages/django_q/conf.py:139: UserWarning: Retry and timeout are misconfigured. Set retry larger than timeout,
#         failure to do so will cause the tasks to be retriggered before completion.
#         See https://django-q.readthedocs.io/en/latest/configure.html#retry for details.
#   warn(
# ...

# %%
from flourish_caregiver.models import CaregiverChildConsent

child_consent= CaregiverChildConsent.objects.filter(subject_identifier='B142-040990558-4-60')
for consent in child_consent:
    consent.first_name = 'Pretty Aone'
    consent.last_name = 'Gaelebale'
    consent.save_base(raw=True)
    
subj=RegisteredSubject.objects.get(subject_identifier='B142-040990558-4-60')
subj.first_name = 'Pretty Aone'
subj.last_name = 'Gaelebale'
subj.initials = 'PAG'
subj.save_base(raw=True)

birth=ChildBirth.objects.get(subject_identifier='B142-040990558-4-60')
birth.first_name = 'Pretty Aone'
birth.last_name = 'Gaelebale'
birth.initials = 'PAG'
birth.save_base(raw=True)
# Out:
# ---------------------------------------------------------------------------
# ImproperlyConfigured                      Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from flourish_caregiver.models import CaregiverChildConsent
#       3 child_consent= CaregiverChildConsent.objects.filter(subject_identifier='B142-040990558-4-60')
#       4 for consent in child_consent:
#
# File ~/source/flourish-code-space/flourish-caregiver/flourish_caregiver/models/__init__.py:1
# ----> 1 from .antenatal_enrollment import AntenatalEnrollment
#       2 from .arvs_pre_pregnancy import ArvsPrePregnancy
#       3 from .breastfeeding_questionnaire import BreastFeedingQuestionnaire
#
# File ~/source/flourish-code-space/flourish-caregiver/flourish_caregiver/models/antenatal_enrollment.py:4
#       2 from django.core.validators import MaxValueValidator, MinValueValidator
#       3 from django.db import models
# ----> 4 from edc_base.model_managers import HistoricalRecords
# ...
